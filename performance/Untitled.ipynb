# %%
import glob, fitdecode
import matplotlib.pyplot as plt 
import numpy as np
from fitparse import FitFile, FitParseError
import pandas as pd
from matplotlib.colors import LogNorm
import matplotlib.cm as cm
from datetime import datetime, timedelta
import warnings; [warnings.filterwarnings("ignore", message=msg) for msg in [
    r"invalid field size .* in definition message .* for type uint32.*",
    r"'field \"native_field_num\".*not found in message \"field_description\".*",
    r"'field \"units\".*not found in message \"field_description\".*"
]]

def semicircles_to_degrees(semicircles):
    return semicircles * (180.0 / 2**31)
    
def fit_to_dataframe(fit_file_path):
    fitfile = FitFile(fit_file_path)

    records = []
    for record in fitfile.get_messages('record'):
        data = {}
        for field in record:
            data[field.name] = field.value
        records.append(data)

    return pd.DataFrame(records)


def fit_to_dataframe(filepath):
    with fitdecode.FitReader(filepath) as fit:
        sport_file, flag_is_run = "none", False
        for frame in fit:
            if frame.frame_type == fitdecode.FIT_FRAME_DATA and frame.name == "session":
                flag_is_run = True#frame.get_value("sport") == "running"
                sport_file = frame.get_value("sport")
                # sub_sport_file = frame.get_value("sub_sport")
                break
                
    if flag_is_run:
        records = []
        with fitdecode.FitReader(filepath) as fit:
            print(f"Found running activity: {sport_file}")# - {frame.get_value('sub_sport')}")
            for frame in fit:
                if frame.frame_type == fitdecode.FIT_FRAME_DATA and frame.name == 'record':
                    record_data = {}
                    for field in frame.fields:
                        record_data[field.name] = field.value
                    records.append(record_data)    
            
            return pd.DataFrame(records)
    else:
        print(f"Skipping: {sport_file}")
    
files = glob.glob("./data/coros/*.fit")
print(f"Detected {len(files)} runs")
# Out:
# Detected 177 runs

# %%
fit_to_dataframe(files[0])
# Out:
# Found running activity: cycling
#     activity_type                 timestamp  distance  heart_rate  \
# 0         cycling 2025-04-29 08:20:16+00:00       0.0         NaN
# 1         cycling 2025-04-29 08:20:17+00:00       0.0       113.0
# 2         cycling 2025-04-29 08:20:18+00:00       0.0       112.0
# 3         cycling 2025-04-29 08:20:19+00:00       0.0       111.0
# 4         cycling 2025-04-29 08:20:20+00:00       0.0       110.0
# ..            ...                       ...       ...         ...
# 686       cycling 2025-04-29 08:31:42+00:00    2648.0       123.0
# 687       cycling 2025-04-29 08:31:43+00:00    2648.5       123.0
# 688       cycling 2025-04-29 08:31:44+00:00    2649.0       123.0
# 689       cycling 2025-04-29 08:31:45+00:00    2649.0       123.0
# 690       cycling 2025-04-29 08:31:46+00:00    2649.0       123.0
#
#      enhanced_altitude  altitude  enhanced_speed  speed  position_lat  \
# 0                  NaN       NaN             NaN    NaN           NaN
# 1                 86.0      86.0           0.886  0.886           NaN
# 2                 86.0      86.0           1.325  1.325           NaN
# 3                 86.0      86.0           1.114  1.114   495036084.0
# 4                 86.0      86.0           2.103  2.103   495036461.0
# ..                 ...       ...             ...    ...           ...
# 686              133.6     133.6           1.136  1.136   495136047.0
# 687              133.6     133.6           0.889  0.889   495136126.0
# 688              133.4     133.4           0.761  0.761   495136402.0
# 689              133.4     133.4           0.761  0.761           NaN
# 690              133.2     133.2           0.000  0.000           NaN
#
#      position_long
# 0              NaN
# 1              NaN
# 2              NaN
# 3       25489116.0
# 4       25488418.0
# ..             ...
# 686     25168347.0
# 687     25168330.0
# 688     25168335.0
# 689            NaN
# 690            NaN
#
# [691 rows x 10 columns]

# %%
field_names = set()
with fitdecode.FitReader(files[0]) as fit:
    for frame in fit:
        if frame.frame_type == fitdecode.FIT_FRAME_DATA and frame.name == 'record':
            for f in frame.fields:
                field_names.add(f.name)
            if hasattr(frame, "developer_fields"):
                for f in frame.developer_fields:
                    field_names.add(f.name)
print(field_names)
# Out:
# {'enhanced_altitude', 'timestamp', 'speed', 'position_long', 'distance', 'position_lat', 'enhanced_speed', 'activity_type', 'heart_rate', 'altitude'}

# %%
import fitdecode
import pandas as pd

def dump_fitdecode_to_txt(fit_path, txt_path):
    with open(txt_path, "w", encoding="utf-8") as f:
        with fitdecode.FitReader(fit_path) as fit:
            for frame in fit:
                f.write(f"Frame type: {frame.frame_type}, Name: {getattr(frame, 'name', 'N/A')}\n")
                try:
                    for field in frame.fields:
                        f.write(f"  {field.name}: {field.value}\n")
                except Exception as e:
                    f.write(f"  Field parse error: {e}\n")
                f.write("\n")
def exhaustive_fit_dump(fit_path, txt_path):
    """
    Dump all frames and fields from a FIT file, including partial/corrupted frames.
    Will not fail on invalid field sizes.
    """
    with open(txt_path, "w", encoding="utf-8") as f:
        try:
            with fitdecode.FitReader(fit_path) as fit:
                for frame in fit:
                    # Frame type and name
                    f.write(f"Frame type: {frame.frame_type}, Name: {getattr(frame, 'name', 'N/A')}\n")
                    
                    # Fields
                    if hasattr(frame, "fields"):
                        for field in frame.fields:
                            try:
                                f.write(f"  {field.name}: {field.value}\n")
                            except Exception as e:
                                f.write(f"  Field parse error: {e}\n")
                    
                    # Developer fields
                    if hasattr(frame, "developer_fields"):
                        for dev_field in frame.developer_fields:
                            try:
                                f.write(f"  Dev {dev_field.name}: {dev_field.value}\n")
                            except Exception as e:
                                f.write(f"  Dev field parse error: {e}\n")
                    
                    f.write("\n")
        except Exception as e:
            f.write(f"Top-level parser error: {e}\n")
    print(f"Exhaustive FIT dump written to {txt_path}")
# Example usage:
exhaustive_fit_dump(files[0], "fit_dump.txt")
# Out:
# Exhaustive FIT dump written to fit_dump.txt

# %%
dfs = [fit_to_dataframe(f) for f in files]
dfs = [df for df in dfs if df is not None]
# Out:
# Found running activity: cycling
# Found running activity: walking
# Found running activity: walking
# Found running activity: running
# Found running activity: generic
# Found running activity: hiking
# Found running activity: cycling
# Found running activity: cycling
# Found running activity: walking
# Found running activity: running
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: cycling
# Found running activity: walking
# Found running activity: running
# Found running activity: training
# Found running activity: training
# Found running activity: generic
# Found running activity: swimming
# Found running activity: running
# Found running activity: running
# Found running activity: swimming
# Found running activity: swimming
# Found running activity: training
# Found running activity: walking
# Found running activity: training
# Found running activity: swimming
# Found running activity: running
# Found running activity: training
# Found running activity: training
# Found running activity: running
# Found running activity: running
# Found running activity: walking
# Found running activity: training
# Found running activity: swimming
# Found running activity: swimming
# Found running activity: running
# Found running activity: cycling
# Found running activity: walking
# Found running activity: training
# Found running activity: swimming
# Found running activity: running
# Found running activity: walking
# Found running activity: training
# Found running activity: generic
# Found running activity: running
# Found running activity: walking
# Found running activity: hiking
# Found running activity: hiking
# Found running activity: training
# Found running activity: walking
# Found running activity: training
# Found running activity: running
# Found running activity: swimming
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: generic
# Found running activity: cycling
# Found running activity: walking
# Found running activity: training
# Found running activity: walking
# Found running activity: running
# Found running activity: running
# Found running activity: training
# Found running activity: training
# Found running activity: swimming
# Found running activity: swimming
# Found running activity: walking
# Found running activity: cycling
# Found running activity: training
# Found running activity: running
# Found running activity: running
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: generic
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: training
# Found running activity: cycling
# Found running activity: walking
# Found running activity: running
# Found running activity: cycling
# Found running activity: hiking
# Found running activity: running
# Found running activity: generic
# Found running activity: walking
# Found running activity: swimming
# Found running activity: walking
# Found running activity: walking
# Found running activity: generic
# Found running activity: cycling
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: training
# Found running activity: running
# Found running activity: cycling
# Found running activity: training
# Found running activity: walking
# Found running activity: generic
# Found running activity: hiking
# Found running activity: running
# Found running activity: walking
# Found running activity: swimming
# Found running activity: walking
# Found running activity: running
# Found running activity: cycling
# Found running activity: swimming
# Found running activity: running
# Found running activity: running
# Found running activity: cycling
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: swimming
# Found running activity: swimming
# Found running activity: floor_climbing
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: running
# Found running activity: training
# Found running activity: running
# Found running activity: swimming
# Found running activity: hiking
# Found running activity: cycling
# Found running activity: cycling
# Found running activity: cycling
# Found running activity: running
# Found running activity: cycling
# Found running activity: walking
# Found running activity: generic
# Found running activity: running
# Found running activity: cycling
# Found running activity: running
# Found running activity: walking
# Found running activity: running
# Found running activity: cycling
# Found running activity: hiking
# Found running activity: running
# Found running activity: cycling
# Found running activity: running
# Found running activity: running
# Found running activity: cycling
# Found running activity: swimming
# Found running activity: training
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: cycling
# Found running activity: hiking
# Found running activity: hiking
# Found running activity: running
# Found running activity: cycling
# Found running activity: running
# Found running activity: hiking
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: running
# Found running activity: running
# Found running activity: running
# Found running activity: generic
# Found running activity: running
# Found running activity: running
# Found running activity: cycling
# Found running activity: running
# Found running activity: swimming
# Found running activity: cycling
# Found running activity: training
# Found running activity: running
# Found running activity: swimming
# Found running activity: running
# Found running activity: walking

# %%
df = dfs[-4]

df
# Out:
#      activity_type                 timestamp  distance  heart_rate  \
# 0          running 2025-05-19 07:53:45+00:00      0.00         NaN
# 1          running 2025-05-19 07:53:46+00:00      0.00         NaN
# 2          running 2025-05-19 07:53:47+00:00      0.00         NaN
# 3          running 2025-05-19 07:53:48+00:00      0.00        89.0
# 4          running 2025-05-19 07:53:49+00:00      0.50        89.0
# ...            ...                       ...       ...         ...
# 2896       running 2025-05-19 08:48:27+00:00   9238.00       171.0
# 2897       running 2025-05-19 08:48:28+00:00   9242.00       171.0
# 2898       running 2025-05-19 08:48:29+00:00   9246.00       171.0
# 2899       running 2025-05-19 08:48:30+00:00   9250.00       171.0
# 2900       running 2025-05-19 08:48:31+00:00   9254.21       171.0
#
#       enhanced_speed  speed  Effort Pace  step_length  enhanced_altitude  \
# 0                NaN    NaN          NaN          NaN                NaN
# 1                NaN    NaN          NaN          NaN                NaN
# 2                NaN    NaN          NaN          NaN                NaN
# 3                NaN    NaN          NaN          NaN                NaN
# 4              0.000  0.000        0.000          NaN                NaN
# ...              ...    ...          ...          ...                ...
# 2896           3.553  3.553        4.236       1170.0              639.0
# 2897           3.561  3.561        4.244       1170.0                NaN
# 2898           3.564  3.564        4.250       1170.0                NaN
# 2899           3.569  3.569        4.255       1180.0                NaN
# 2900             NaN    NaN          NaN          NaN              640.0
#
#       altitude  cadence  power  accumulated_power  position_lat  position_long
# 0          NaN      NaN    NaN                NaN           NaN            NaN
# 1          NaN      NaN    NaN                NaN           NaN            NaN
# 2          NaN      NaN    NaN                NaN           NaN            NaN
# 3          NaN      NaN    NaN                NaN           NaN            NaN
# 4          NaN      NaN    NaN                NaN           NaN            NaN
# ...        ...      ...    ...                ...           ...            ...
# 2896     639.0     90.0  292.0           684901.0   482284672.0    -44312591.0
# 2897       NaN     91.0  293.0           685194.0   482285028.0    -44312269.0
# 2898       NaN     91.0  293.0           685487.0   482285384.0    -44311946.0
# 2899       NaN     91.0  294.0           685781.0   482286016.0    -44311274.0
# 2900     640.0      NaN    NaN                NaN   482286647.0    -44310601.0
#
# [2901 rows x 15 columns]

# %%
# --- assuming your dataframe is called df ---
# columns: ['timestamp', 'step_length', 'cadence', 'power', 'speed']

# 1️⃣ Ensure timestamps are datetime and sorted
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)

# 2️⃣ Smooth raw signals with rolling mean
window = 20  # adjust for your data frequency (e.g. 10–30 samples)
metrics = ['step_length', 'cadence', 'power', 'speed']

for col in metrics:
    df[f'{col}_smooth'] = df[col].rolling(window, center=True).mean()

# 3️⃣ Compute normalized absolute differences (anomaly indicators)
for col in metrics:
    diff = df[col].diff().abs()
    df[f'{col}_anomaly'] = (diff - diff.mean()) / diff.std()

# 4️⃣ Build composite anomaly index
df['anomaly_index'] = df[[f'{c}_anomaly' for c in metrics]].fillna(0).sum(axis=1)
df['anomaly_index_smooth'] = df['anomaly_index'].rolling(window*2, center=True).mean()

# 5️⃣ Create figure with two subplots
fig, axes = plt.subplots(2, 1, figsize=(14, 9), sharex=True, gridspec_kw={'height_ratios': [1, 2]})

# --- (A) Anomaly evolution ---
axes[0].plot(df['timestamp'], df['anomaly_index_smooth'], color='black', lw=2, label='Composite anomaly index')
for col in metrics:
    axes[0].plot(df['timestamp'], df[f'{col}_anomaly'], alpha=0.35, label=f'{col} anomaly')
axes[0].set_title("Behavioral Anomaly Evolution (Composite + Individual Metrics)")
axes[0].set_ylabel("Normalized anomaly intensity")
axes[0].legend()
axes[0].grid(True, alpha=0.3)

# --- (B) Smoothed metrics evolution ---
for j, col in enumerate(metrics):
    if j == 3:
        axes[1].plot(df['timestamp'], df[f'{col}'], lw=1.5, label=f'{col} (smoothed)')
axes[1].set_title("Smoothed Metric Evolution Over Time")
axes[1].set_xlabel("Time")
axes[1].set_ylabel("Metric value (normalized scale)")
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
df
# Out:
#       activity_type                 timestamp  distance  enhanced_speed  \
# 13               11 2025-05-17 15:05:40+00:00       2.0           0.831
# 14               11 2025-05-17 15:05:41+00:00       2.0           1.664
# 15               11 2025-05-17 15:05:42+00:00       4.0           1.706
# 16               11 2025-05-17 15:05:43+00:00       6.0           1.747
# 17               11 2025-05-17 15:05:44+00:00       7.5           1.753
# ...             ...                       ...       ...             ...
# 8737             11 2025-05-17 20:43:29+00:00    7961.0           1.042
# 8738             11 2025-05-17 20:43:30+00:00    7962.0           1.039
# 8739             11 2025-05-17 20:43:31+00:00    7963.0           1.033
# 8740             11 2025-05-17 20:43:32+00:00    7964.0           1.028
# 8741             11 2025-05-17 20:43:33+00:00    7965.0           0.514
#
#       speed  enhanced_altitude  altitude  heart_rate  step_length  cadence  \
# 13    0.831              116.0     116.0        97.0          NaN      NaN
# 14    1.664              116.0     116.0        97.0          NaN      NaN
# 15    1.706              116.0     116.0        97.0        770.0      NaN
# 16    1.747              116.0     116.0        98.0        780.0      NaN
# 17    1.753              116.0     116.0        98.0        780.0     67.0
# ...     ...                ...       ...         ...          ...      ...
# 8737  1.042              109.0     109.0       104.0        610.0     51.0
# 8738  1.039              109.0     109.0       104.0        610.0     51.0
# 8739  1.033              109.0     109.0       104.0        610.0     50.0
# 8740  1.028              109.0     109.0       104.0        610.0     50.0
# 8741  0.514              109.0     109.0       104.0        300.0     25.0
#
#       position_lat  position_long       pace
# 13             NaN            NaN  20.056157
# 14             NaN            NaN  10.016026
# 15             NaN            NaN   9.769441
# 16             NaN            NaN   9.540164
# 17             NaN            NaN   9.507511
# ...            ...            ...        ...
# 8737           NaN            NaN  15.994882
# 8738           NaN            NaN  16.041065
# 8739           NaN            NaN  16.134237
# 8740           NaN            NaN  16.212711
# 8741           NaN            NaN  32.425422
#
# [6106 rows x 13 columns]

# %%
def semicircles_to_degrees(semicircles):
    return semicircles * (180.0 / 2**31)
def degrees_to_semicircles(degrees):
    return degrees / (180.0 / 2**31)
    
time, pace, heart_rate, lat, lon = [], [], [], [], []
alt, step_len, pow, cad, dist = [], [], [], [], []
alt_smooth, dist_smooth, delta_alt, delta_dist = [], [], [], []
grade, gap, terrain, efficiency, efficiency_adj = [], [], [], [], []
terrain = []

for i, df in enumerate(dfs):
    if ("heart_rate" not in df.columns) or ("position_lat" not in df.columns) or ("power" not in df.columns):
        continue
        
    df = df[~np.isnan(df["speed"])]
    df = df[df["speed"] != 0]
    
    time.append(np.array(df["timestamp"]))
    df["pace"] = 1000 / df["enhanced_speed"] / 60

    pace.append(np.array(df["pace"])); heart_rate.append(np.array(df["heart_rate"])); dist.append(np.array(df["distance"]))
    lat.append(semicircles_to_degrees(np.array(df["position_lat"]))); lon.append(semicircles_to_degrees(np.array(df["position_long"]))) 
    
    alt.append(np.array(df["enhanced_altitude"])); step_len.append(np.array(df["step_length"]));
    pow.append(np.array(df["power"])); cad.append(np.array(df["cadence"]));

    
    df['alt_smooth'] = df['enhanced_altitude'].rolling(window=5, center=True).mean()
    df['dist_smooth'] = df['distance'].rolling(window=5, center=True).mean()
    df['delta_alt'], df['delta_dist'] = df['alt_smooth'].diff(), df['dist_smooth'].diff()
    df['grade'] = 100 * (df['delta_alt'] / df['delta_dist'])
    df['gap'] = df["pace"] * (1 + df['grade'] / 10)

    grade.append(df["grade"]); gap.append(df["gap"])
    alt_smooth.append(df["alt_smooth"]); dist_smooth.append(df["dist_smooth"])
    delta_alt.append(df["delta_alt"]); delta_dist.append(df["delta_dist"])
    
    df['terrain'] = pd.cut(df['grade'], bins=[-np.inf, -3, 3, np.inf], labels=[-1, 0, 1])
    df.groupby('terrain', observed=True)[['pace', 'heart_rate', 'power']].mean()
    
    df['efficiency'] = df['enhanced_speed'] / df['power']
    df['efficiency_adj'] = df['efficiency'] / (1 + df['grade'].abs() / 10)

    terrain.append(np.array(df["terrain"]))

# %%
for i in range(len(lon)):
    fig, ax = plt.subplots(figsize=(6, 5))


    # plt.plot(lon[i], lat[i], color="darkblue", ls="-", lw=2)
    from matplotlib.colors import LinearSegmentedColormap

    # Define a custom colormap for altitude
    colors = [
        (0.0, "#f5e663"),   # yellow
        (0.33, "#f28e2b"),  # orange
        (0.66, "#e63946"),   # red
        (1.0, "#8b4513")
    ]

    altitude_cmap = LinearSegmentedColormap.from_list("altitude_cmap", colors)

    plt.scatter(lon[i], lat[i], c=alt[i], marker=".", cmap=altitude_cmap)

    ax.set_axis_off()
    fig.patch.set_alpha(0)        # Transparent figure background
    ax.patch.set_alpha(0)         # Transparent axes background

    # Save as PNG with transparent background
    plt.savefig("trail_path.png", dpi=300, bbox_inches='tight', pad_inches=0, transparent=True)
    plt.show()

# %%
import contextily as cx
import geopandas
import rasterio
from rasterio.plot import show as rioshow
import matplotlib.pyplot as plt
from geodatasets import get_path

# %%
data_url = "https://ndownloader.figshare.com/files/20232174"
db = geopandas.read_file(data_url)
# Out:
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/pyogrio/raw.py:198: RuntimeWarning: File /vsicurl/https://ndownloader.figshare.com/files/20232174 has GPKG application_id, but non conformant file extension
#   return ogr_read(

# %%
nightlights = cx.providers.NASAGIBS.ViirsEarthAtNight2012
ireland = cx.Place("Spain", source=nightlights)

# %%
import xyzservices.providers as xyz
k = 0
delta = 0.02
min_lat, max_lat = np.nanmean(lat[k]) - delta, np.nanmean(lat[k]) + delta
min_lon, max_lon = np.nanmean(lon[k]) - delta, np.nanmean(lon[k]) + delta


extent = [min_lon, max_lon, min_lat, max_lat]

fig, ax = plt.subplots(figsize=(9, 9))

ghent_img, ghent_ext = cx.bounds2img(
    min_lon, min_lat, max_lon, max_lat, ll=True,source=xyz.OpenTopoMap
    # OpenTopoMap, CyclOSM, Esri.WorldTopoMap, Esri.WorldImagery, Esri.WorldShadedRelief
)

import geopandas as gpd
from shapely.geometry import LineString
ax.imshow(ghent_img, extent=[min_lon, max_lon, min_lat, max_lat], aspect="auto")

line = LineString(zip(degrees_to_semicircles(lon[k]), degrees_to_semicircles(lat[k])))
gdf = gpd.GeoDataFrame(geometry=[line], crs="EPSG:4326").to_crs(epsg=3857)
gdf.plot(ax=ax, color="red", linestyle="--")


# for k in [k]:#range(len(lon)):
#     plt.plot(lon[k], lat[k], color="r", ls="--")
# Out:
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/shapely/constructive.py:556: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/shapely/constructive.py:556: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)
# <Axes: >

# %%
fig, ax = plt.subplots(figsize=(10, 10))

# Plot map
ax.imshow(ghent_img, extent=ghent_ext, interpolation='bilinear')

# Plot line
gdf.plot(ax=ax, linewidth=2, color='red')

# Ensure extent is set
ax.set_xlim(ghent_ext[0], ghent_ext[2])
ax.set_ylim(ghent_ext[1], ghent_ext[3])

plt.show()
# Out:
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/shapely/constructive.py:556: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/shapely/constructive.py:556: RuntimeWarning: invalid value encountered in normalize
#   return lib.normalize(geometry, **kwargs)

# %%
k = 0

delta = 0.02
min_lat, max_lat = np.nanmean(lat[k]) - delta, np.nanmean(lat[k]) + delta
min_lon, max_lon = np.nanmean(lon[k]) - delta, np.nanmean(lon[k]) + delta


ghent_img, ghent_ext = cx.bounds2img(min_lon, min_lat, max_lon, max_lat,
                                     ll=True,
                                     source=xyz.NASAGIBS.BlueMarble
                                    )


f, ax = plt.subplots(1, figsize=(8, 15))
ax.imshow(ghent_img, extent=[min_lon, max_lon, min_lat, max_lat], aspect="auto")

for k in [k]:#range(len(lon)):
    plt.plot(lon[k], lat[k])
# Out:
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/contextily/tile.py:645: UserWarning: The inferred zoom level of 15 is not valid for the current tile provider (valid zooms: 0 - 8).
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:453, in _retryer(tile_url, wait, max_retries)
#     452 request = requests.get(tile_url, headers={"user-agent": USER_AGENT})
# --> 453 request.raise_for_status()
#     454 with io.BytesIO(request.content) as image_stream:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/EPSG3857_500m/8/95/129.jpeg
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:453, in _retryer(tile_url, wait, max_retries)
#     452 request = requests.get(tile_url, headers={"user-agent": USER_AGENT})
# --> 453 request.raise_for_status()
#     454 with io.BytesIO(request.content) as image_stream:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/EPSG3857_500m/8/95/129.jpeg
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:453, in _retryer(tile_url, wait, max_retries)
#     452 request = requests.get(tile_url, headers={"user-agent": USER_AGENT})
# --> 453 request.raise_for_status()
#     454 with io.BytesIO(request.content) as image_stream:
#
# File ~/anaconda3/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/EPSG3857_500m/8/95/129.jpeg
#
# During handling of the above exception, another exception occurred:
#
# HTTPError                                 Traceback (most recent call last)
# Cell In[300], line 8
#       4 min_lat, max_lat = np.nanmean(lat[k]) - delta, np.nanmean(lat[k]) + delta
#       5 min_lon, max_lon = np.nanmean(lon[k]) - delta, np.nanmean(lon[k]) + delta
# ----> 8 ghent_img, ghent_ext = cx.bounds2img(min_lon, min_lat, max_lon, max_lat,
#       9                                      ll=True,
#      10                                      source=xyz.NASAGIBS.BlueMarble
#      11                                     )
#      14 f, ax = plt.subplots(1, figsize=(8, 15))
#      15 ax.imshow(ghent_img, extent=[min_lon, max_lon, min_lat, max_lat], aspect="auto")
#
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:283, in bounds2img(w, s, e, n, zoom, source, ll, wait, max_retries, n_connections, use_cache, zoom_adjust)
#     279 preferred_backend = (
#     280     "threads" if (n_connections == 1 or not use_cache) else "processes"
#     281 )
#     282 fetch_tile_fn = memory.cache(_fetch_tile) if use_cache else _fetch_tile
# --> 283 arrays = Parallel(n_jobs=n_connections, prefer=preferred_backend)(
#     284     delayed(fetch_tile_fn)(tile_url, wait, max_retries) for tile_url in tile_urls
#     285 )
#     286 # merge downloaded tiles
#     287 merged, extent = _merge_tiles(tiles, arrays)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:1085, in Parallel.__call__(self, iterable)
#    1076 try:
#    1077     # Only set self._iterating to True if at least a batch
#    1078     # was dispatched. In particular this covers the edge
#    (...)
#    1082     # was very quick and its callback already dispatched all the
#    1083     # remaining jobs.
#    1084     self._iterating = False
# -> 1085     if self.dispatch_one_batch(iterator):
#    1086         self._iterating = self._original_iterator is not None
#    1088     while self.dispatch_one_batch(iterator):
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:594, in MemorizedFunc.__call__(self, *args, **kwargs)
#     593 def __call__(self, *args, **kwargs):
# --> 594     return self._cached_call(args, kwargs)[0]
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:537, in MemorizedFunc._cached_call(self, args, kwargs, shelving)
#     534         must_call = True
#     536 if must_call:
# --> 537     out, metadata = self.call(*args, **kwargs)
#     538     if self.mmap_mode is not None:
#     539         # Memmap the output at the first call to be consistent with
#     540         # later calls
#     541         if self._verbose:
#
# File ~/anaconda3/lib/python3.11/site-packages/joblib/memory.py:779, in MemorizedFunc.call(self, *args, **kwargs)
#     777 if self._verbose > 0:
#     778     print(format_call(self.func, args, kwargs))
# --> 779 output = self.func(*args, **kwargs)
#     780 self.store_backend.dump_item(
#     781     [func_id, args_id], output, verbose=self._verbose)
#     783 duration = time.time() - start_time
#
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:313, in _fetch_tile(tile_url, wait, max_retries)
#     312 def _fetch_tile(tile_url, wait, max_retries):
# --> 313     array = _retryer(tile_url, wait, max_retries)
#     314     return array
#
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:471, in _retryer(tile_url, wait, max_retries)
#     469     time.sleep(wait)
#     470     max_retries -= 1
# --> 471     request = _retryer(tile_url, wait, max_retries)
#     472 else:
#     473     raise requests.HTTPError("Connection reset by peer too many times. "
#     474                              f"Last message was: {request.status_code} "
#     475                              f"Error: {request.reason} for url: {request.url}")
#
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:471, in _retryer(tile_url, wait, max_retries)
#     469     time.sleep(wait)
#     470     max_retries -= 1
# --> 471     request = _retryer(tile_url, wait, max_retries)
#     472 else:
#     473     raise requests.HTTPError("Connection reset by peer too many times. "
#     474                              f"Last message was: {request.status_code} "
#     475                              f"Error: {request.reason} for url: {request.url}")
#
# File ~/anaconda3/lib/python3.11/site-packages/contextily/tile.py:473, in _retryer(tile_url, wait, max_retries)
#     471     request = _retryer(tile_url, wait, max_retries)
#     472 else:
# --> 473     raise requests.HTTPError("Connection reset by peer too many times. "
#     474                              f"Last message was: {request.status_code} "
#     475                              f"Error: {request.reason} for url: {request.url}")
#
# HTTPError: Connection reset by peer too many times. Last message was: 400 Error: Bad Request for url: https://gibs.earthdata.nasa.gov/wmts/epsg3857/best/BlueMarble_NextGeneration/default/EPSG3857_500m/8/95/129.jpeg

# %%
# Out:
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 43503 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 317); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 38561 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 123275); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 78); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 78); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 99); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 99); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 138); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 138); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 178); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 178); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 219); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 219); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 243); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 243); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "units" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 267); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 267); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 64987 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 3900 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 294); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 1492 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 89140); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 261 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 14572 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 307); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 10021 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 101683); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 265); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 149735); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 16392 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 20663 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 95449 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 100045); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 95400 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 258018); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 21127 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 84529); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 76482 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 35611 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 1972 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 298); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 99979); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 35439 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 20286 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 30218 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 108200); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 25736 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 0; chunk_offset: 285); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 80202); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 1235 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 26167 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 146449); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 87966 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 14773 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 190477); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 5684 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 253 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 131886); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 65896); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 24958 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 36799 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 24472 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 11760 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 97383); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 4654 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 81070); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 36059 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 3235 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 4087); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 101431 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 291715); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 91743); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 178580 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 211976); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 9031 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 264421); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 30713 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 61643); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 17788 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 86497 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 284863); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 232 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 42079 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 9300 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 135396); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 35836); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 24244 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 2510 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 11; chunk_offset: 5417); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 2252 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 171808); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 11497 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 42355); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 52883 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 153877); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 1708 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 4905 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 166101); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 7616 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 19250); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 60697 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 120877); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 22801 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 84781); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 26945); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 30123 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 148263); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 38145 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 12901 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 63379); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 48631 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 106111); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 41593 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 515485); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 1175 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 233057); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 3434 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 6907 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 47431); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 12508 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 98572); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 10447); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 97792); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 484 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 56764 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 104866); adding dummy dev data...
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 16209 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:584: UserWarning: invalid field size 1 in definition message @ 6704 for type uint32 (expected a multiple of 4)
#   warnings.warn(msg)
# /home/jjimenezq/anaconda3/lib/python3.11/site-packages/fitdecode/reader.py:909: UserWarning: 'field "native_field_num" (idx #0) not found in message "field_description"' (local_mesg_num: 8; chunk_offset: 148262); adding dummy dev data...
#   warnings.warn(msg)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'step_length'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 18
#      16 pace.append(np.array(df["pace"])); heart_rate.append(np.array(df["heart_rate"])); dist.append(np.array(df["distance"]))
#      17 lat.append(semicircles_to_degrees(np.array(df["position_lat"]))); lon.append(semicircles_to_degrees(np.array(df["position_long"])))
# ---> 18 alt.append(np.array(df["enhanced_altitude"])); step_len.append(np.array(df["step_length"]));
#      19 pow.append(np.array(df["power"])); cad.append(np.array(df["cadence"]));
#      22 df['alt_smooth'] = df['enhanced_altitude'].rolling(window=5, center=True).mean()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'step_length'

# %%
k = 0
from scipy.ndimage import gaussian_filter1d

terrain_colors = {-1: "lightblue", 0: "0.8", 1: "lightcoral"}

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(8, 6))

for ax in [ax1, ax2]:
    start_idx = 0
    terrain_smooth = gaussian_filter1d(terrain[k].astype(float), sigma=10)
    for i in range(1, len(time[k])):
        if terrain_smooth[i] != terrain_smooth[i-1] and not np.isnan(terrain_smooth[i-1]):
            start_time = dist[k][start_idx]
            end_time = dist[k][i-1]
    
            ax.axvspan(start_time, end_time,
                        color=terrain_colors[np.round(terrain_smooth[i-1])],
                        alpha=1,)  # semi-transparent
    
            start_idx = i
        
ax2.plot(dist[k], gaussian_filter1d(alt_smooth[k], 3), "-k")
ax1.plot(dist[k], pace[k], "-k")


ax2.fill_between(dist[k], gaussian_filter1d(alt_smooth[k], 3), color="0.35", alpha=0.3)

ax1.set_ylim(10, 3)
for ax in [ax1, ax2]:
    ax2.set_ylim(np.nanmin(alt[k])-5 if np.nanmin(alt[k]) >= 0.0 else -5)
    ax2.set_xlim(np.nanmin(dist[k]), np.nanmax(dist[k]))
plt.show()

# %%
for k in [0]:
    plt.plot(lon[k], lat[k])

# %%
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import cartopy.feature as cfeature

delta = 0.02
min_lat, max_lat = np.nanmean(lat[k]) - delta, np.nanmean(lat[k]) + delta
min_lon, max_lon = np.nanmean(lon[k]) - delta, np.nanmean(lon[k]) + delta

fig = plt.figure(figsize=(8, 8))
ax = plt.axes(projection=ccrs.PlateCarree())
ax.set_extent([min_lon, max_lon, min_lat, max_lat])

for k in [0]:
    plt.plot(lon[k], lat[k])

# Add land with natural earth shading
ax.add_feature(cfeature.LAND.with_scale('10m'), facecolor='lightgreen')

# Add ocean with color
ax.add_feature(cfeature.OCEAN.with_scale('10m'), facecolor='lightblue')

# Add lakes and rivers
ax.add_feature(cfeature.LAKES.with_scale('10m'), facecolor='blue', alpha=0.5)
ax.add_feature(cfeature.RIVERS.with_scale('10m'), edgecolor='blue')

# Add coastlines with high resolution
ax.coastlines(resolution='10m')

# Optionally add gridlines
gl = ax.gridlines(draw_labels=True)
gl.top_labels = False
gl.right_labels = False

plt.show()

# %%
plt.hist2d(df['pace'], df['heart_rate'], bins=50, cmap='plasma')
plt.colorbar(label='Count')
plt.title('Heart Rate vs Pace')
plt.xlabel('Pace (min/km)')
plt.ylabel('Heart Rate (bpm)')
plt.show()

# %%
plt.scatter(df['distance'], df['altitude'], c=df['pace'], cmap='coolwarm', s=3)
plt.colorbar(label='Pace (min/km)')
plt.title('Elevation Profile')
plt.xlabel('Distance (m)')
plt.ylabel('Altitude (m)')
plt.show()

# %%
mask = ~np.isnan(df["grade"])
plt.hist2d(
    df['grade'][mask], 
    df['power'][mask], 
    bins=50, cmap='viridis')
plt.colorbar(label='Count')
plt.title('Power vs Grade')
plt.xlabel('Grade (%)')
plt.ylabel('Power (W)')
plt.show()

# %%
df['pace_roll'] = df['pace'].rolling(10).mean()
df['hr_roll'] = df['heart_rate'].rolling(10).mean()

plt.plot(df['timestamp'], df['pace_roll'], label='Pace (rolling)')
plt.plot(df['timestamp'], df['hr_roll'], label='Heart Rate (rolling)')
plt.title('Rolling Pace and Heart Rate')
plt.xlabel('Time')
plt.ylabel('Value')
plt.legend()
plt.show()

# %%
plt.scatter(df['cadence'], df['step_length'], c=df['power'], cmap='inferno', s=5)
plt.colorbar(label='Power (W)')
plt.title('Cadence vs Step Length colored by Power')
plt.xlabel('Cadence (spm)')
plt.ylabel('Step Length (m)')
plt.show()

# %%
plt.scatter(lon, lat, c=df['altitude'], cmap='terrain', s=2)
plt.colorbar(label='Altitude (m)')
plt.title('Trail Route by Elevation')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
plt.hist(df['pace'], bins=40, color='skyblue', edgecolor='black')
plt.title('Distribution of Pace')
plt.xlabel('Pace (min/km)')
plt.ylabel('Frequency')
plt.show()

# %%
hr_zones = [100, 120, 140, 160, 180, 200]
zone_labels = [f"{hr_zones[i]}–{hr_zones[i+1]}" for i in range(len(hr_zones)-1)]

zone_counts = pd.cut(df['heart_rate'], bins=hr_zones).value_counts().sort_index()
plt.bar(zone_labels, zone_counts)
plt.title('Time in Heart Rate Zones')
plt.xlabel('HR Zone (bpm)')
plt.ylabel('Time Points')
plt.xticks(rotation=45)
plt.show()

# %%
time_norm = (df['timestamp'] - df['timestamp'].min()).dt.total_seconds()
time_norm = time_norm / time_norm.max()

colors = cm.inferno(time_norm)

plt.figure(figsize=(8, 6))
plt.scatter(lon, lat, c=colors, s=2)
plt.title('Trail Path Colored by Time')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(12, 2))
plt.scatter(df['timestamp'], df['altitude'], c=df['power'], cmap='hot', s=2)
plt.colorbar(label='Power (W)')
plt.title('Power Flow Over Elevation')
plt.xlabel('Time')
plt.ylabel('Altitude')
plt.tight_layout()
plt.show()

# %%
alt = df['altitude'].rolling(10).mean()
plt.fill_between(df['distance'], alt, color='sienna', alpha=0.3)
plt.plot(df['distance'], alt, color='black', linewidth=1)
plt.title('Shaded Elevation Profile')
plt.xlabel('Distance (m)')
plt.ylabel('Altitude (m)')
plt.show()

# %%
from matplotlib.collections import LineCollection

mask = ~np.isnan(df["grade"])

x = df['distance'][mask].values
y = df['altitude'][mask].values
points = np.array([x, y]).T.reshape(-1, 1, 2)
segments = np.concatenate([points[:-1], points[1:]], axis=1)

colors = df['grade'].clip(-30, 30)  # clip extreme values
norm = plt.Normalize(-30, 30)
lc = LineCollection(segments, cmap='coolwarm', norm=norm)
lc.set_array(colors)
lc.set_linewidth(2)

fig, ax = plt.subplots()
line = ax.add_collection(lc)
plt.colorbar(line, label='Grade (%)')
ax.set_xlim(x.min(), x.max())
ax.set_ylim(y.min(), y.max())
plt.title('Gradient-Encoded Elevation Profile')
plt.xlabel('Distance (m)')
plt.ylabel('Altitude (m)')
plt.show()

# %%
import numpy as np

times = df['timestamp'].dt.time
hours = df['timestamp'].dt.hour + df['timestamp'].dt.minute / 60
radii = df['heart_rate']

theta = (hours / 24) * 2 * np.pi  # 24-hour circle

plt.figure(figsize=(6, 6))
ax = plt.subplot(111, polar=True)
ax.scatter(theta, radii, c=radii, cmap='cool', s=3)
ax.set_theta_direction(-1)
ax.set_theta_offset(np.pi / 2)
plt.title("Heart Rate Over 24-Hour Clock", pad=20)
plt.show()

# %%
plt.scatter(df['pace'], df['power'], c=df['grade'], cmap='bwr', s=5)
plt.xlabel('Pace (min/km)')
plt.ylabel('Power (W)')
plt.title('Power vs Pace (Color = Grade)')
plt.colorbar(label='Grade (%)')
plt.grid(True)
plt.show()

# %%
plt.scatter(grade, pace)
plt.

# %%
avg_metrics = {
    'Pace': df['pace'].mean(),
    'Heart Rate': df['heart_rate'].mean(),
    'Cadence': df['cadence'].mean(),
    'Power': df['power'].mean(),
    'Step Length': df['step_length'].mean(),
    'Vert Rate': df['altitude'].diff().fillna(0).mean() / (df['timestamp'].diff().dt.total_seconds().fillna(1).mean() / 60)
}

labels = list(avg_metrics.keys())
values = list(avg_metrics.values())

angles = np.linspace(0, 2 * np.pi, len(labels), endpoint=False).tolist()
values += values[:1]
angles += angles[:1]

fig, ax = plt.subplots(figsize=(6, 6), subplot_kw=dict(polar=True))
ax.plot(angles, values, 'o-', linewidth=2)
ax.fill(angles, values, alpha=0.3)
ax.set_thetagrids(np.degrees(angles[:-1]), labels)
plt.title("Trail Run Fitness Fingerprint")
plt.show()

# %%
plt.scatter(df["position_lat"], df["position_long"], c=df["heart_rate"], alpha=0.1)

# %%
plt.plot(df[""])

# %%
# Print the number of tracks
print("Number of tracks:", len(gpx.tracks))

# Get the first track
track = gpx.tracks[0]
print("Track object:", track)

# Print track type and name
print("Track type:", track.type)
print("Track name:", track.name)

# Print the segments
print("Track segments:", track.segments)
# Out:
# Number of tracks: 1
# Track object: GPXTrack(name='FIT Activity', segments=[GPXTrackSegment(points=[...])])
# Track type: running
# Track name: FIT Activity
# Track segments: [GPXTrackSegment(points=[...])]

# %%
# Get the first segment of the track
segment = track.segments[0]

# Print number of points in the segment
print("Number of points in segment:", len(segment.points))

# Get a random point (e.g., the 45th point, index 44)
random_point = segment.points[44]
print("Random point object:", random_point)

# Print latitude, longitude, elevation, and time of the point
print("Latitude:", random_point.latitude)
print("Longitude:", random_point.longitude)
print("Elevation:", random_point.elevation)
print("Time:", random_point.time)
# Out:
# Number of points in segment: 2765
# Random point object: [trkpt:38.2988389,-0.7175469@124.0@2025-07-28 18:22:35+00:00]
# Latitude: 38.2988389
# Longitude: -0.7175469
# Elevation: 124.0
# Time: 2025-07-28 18:22:35+00:00

# %%
# Access extensions of the random point
print("Extensions:", random_point.extensions)

# Get the first extension element
tpe = random_point.extensions[0]

# Print each child tag and its text content
print("TrackPointExtension contents:")
for child in tpe:
    print(child.tag, child.text)
# Out:
# Extensions: [<Element {http://www.garmin.com/xmlschemas/TrackPointExtension/v1}TrackPointExtension at 0x7c4f8cc7e500>, <Element power at 0x7c4f8cc7f680>]
# TrackPointExtension contents:
# {http://www.garmin.com/xmlschemas/TrackPointExtension/v1}hr 137
# {http://www.garmin.com/xmlschemas/TrackPointExtension/v1}cad 81

# %%
print(segment.length_2d(), segment.length_3d())
# Out:
# 7853.654006613418 8415.366679428695

# %%
    with open(file) as f:
        gpx = gpxpy.parse(f)

# %%
gpx.tracks[0].segments[0].points
# Out:
# [GPXTrackPoint(38.2980029, -0.7168041, elevation=0.0, time=datetime.datetime(2025, 7, 28, 18, 21, 51, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2980352, -0.7168134, elevation=0.0, time=datetime.datetime(2025, 7, 28, 18, 21, 52, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2980677, -0.7168227, elevation=0.0, time=datetime.datetime(2025, 7, 28, 18, 21, 53, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.298089, -0.7168346, elevation=0.0, time=datetime.datetime(2025, 7, 28, 18, 21, 54, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981103, -0.7168466, elevation=119.0, time=datetime.datetime(2025, 7, 28, 18, 21, 55, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981274, -0.7168628, elevation=119.0, time=datetime.datetime(2025, 7, 28, 18, 21, 56, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981445, -0.7168791, elevation=119.0, time=datetime.datetime(2025, 7, 28, 18, 21, 57, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981571, -0.7168914, elevation=119.0, time=datetime.datetime(2025, 7, 28, 18, 21, 58, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981696, -0.7169038, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 21, 59, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2981821, -0.7169162, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2982029, -0.7169372, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 1, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2982237, -0.7169581, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 2, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2982446, -0.7169803, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2982656, -0.7170025, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2982849, -0.717025, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2983042, -0.7170475, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2983216, -0.7170683, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.298339, -0.7170892, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2983543, -0.7171094, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2983699, -0.7171297, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2983852, -0.7171498, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2984006, -0.7171699, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.2984175, -0.717189, elevation=120.0, time=datetime.datetime(2025, 7, 28, 18, 22, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.
tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088739, -0.6989822, elevation=213.0, time=datetime.datetime(2025, 7, 28, 18, 38, 3, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088738, -0.6989529, elevation=214.0, time=datetime.datetime(2025, 7, 28, 18, 38, 4, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088725, -0.6989245, elevation=214.0, time=datetime.datetime(2025, 7, 28, 18, 38, 5, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088712, -0.6988962, elevation=214.0, time=datetime.datetime(2025, 7, 28, 18, 38, 6, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088688, -0.6988695, elevation=214.0, time=datetime.datetime(2025, 7, 28, 18, 38, 7, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088665, -0.6988429, elevation=214.0, time=datetime.datetime(2025, 7, 28, 18, 38, 8, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088606, -0.6988182, elevation=215.0, time=datetime.datetime(2025, 7, 28, 18, 38, 9, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088547, -0.6987935, elevation=215.0, time=datetime.datetime(2025, 7, 28, 18, 38, 10, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088434, -0.6987707, elevation=215.0, time=datetime.datetime(2025, 7, 28, 18, 38, 11, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088321, -0.698748, elevation=215.0, time=datetime.datetime(2025, 7, 28, 18, 38, 12, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088167, -0.6987293, elevation=215.0, time=datetime.datetime(2025, 7, 28, 18, 38, 13, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088014, -0.6987107, elevation=216.0, time=datetime.datetime(2025, 7, 28, 18, 38, 14, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087865, -0.6986937, elevation=216.0, time=datetime.datetime(2025, 7, 28, 18, 38, 15, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087719, -0.6986766, elevation=216.0, time=datetime.datetime(2025, 7, 28, 18, 38, 16, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087692, -0.6986604, elevation=216.0, time=datetime.datetime(2025, 7, 28, 18, 38, 17, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087665, -0.698644, elevation=216.0, time=datetime.datetime(2025, 7, 28, 18, 38, 18, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087797, -0.6986333, elevation=217.0, time=datetime.datetime(2025, 7, 28, 18, 38, 19, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3087929, -0.6986225, elevation=217.0, time=datetime.datetime(2025, 7, 28, 18, 38, 20, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.308816, -0.6986191, elevation=217.0, time=datetime.datetime(2025, 7, 28, 18, 38, 21, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088392, -0.6986157, elevation=217.0, time=datetime.datetime(2025, 7, 28, 18, 38, 22, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088667, -0.6986189, elevation=217.0, time=datetime.datetime(2025, 7, 28, 18, 38, 23, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3088942, -0.6986222, elevation=218.0, time=datetime.datetime(2025, 7, 28, 18, 38, 24, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3089232, -0.6986295, elevation=218.0, time=datetime.datetime(2025, 7, 28, 18, 38, 25, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3089522, -0.6986369, elevation=218.0, time=datetime.datetime(2025, 7, 28, 18, 38, 26, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3089811, -0.6986447, elevation=219.0, time=datetime.datetime(2025, 7, 28, 18, 38, 27, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3090101, -0.6986526, elevation=219.0, time=datetime.datetime(2025, 7, 28, 18, 38, 28, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3090377, -0.6986602, elevation=220.0, time=datetime.datetime(2025, 7, 28, 18, 38, 29, tzinfo=SimpleTZ('Z'))),
#  GPXTrackPoint(38.3090653, -0.6986678, elevation=220.0, time=datetime.datetime(2025, 7, 28, 18, 38, 30, tzinfo=SimpleTZ('Z'))),
#  ...]

# %%
segment.points

# %%
parse_gpx.get_gpx_point_data(segment.points[0])
# Out:
# {'latitude': 38.298002,
#  'longitude': -0.7168041,
#  'elevation': 119.0,
#  'time': datetime.datetime(2025, 7, 28, 18, 21, 51, tzinfo=SimpleTZ('Z'))}

# %%
df = parse_gpx.get_dataframe_from_gpx(file)
df
# Out:
#        latitude  longitude  elevation                      time  heart_rate  \
# 0     38.298002  -0.716804      119.0 2025-07-28 18:21:51+00:00         NaN
# 1     38.298034  -0.716813      119.0 2025-07-28 18:21:52+00:00         NaN
# 2     38.298067  -0.716823      119.0 2025-07-28 18:21:53+00:00         NaN
# 3     38.298088  -0.716835      119.0 2025-07-28 18:21:54+00:00         NaN
# 4     38.298110  -0.716847      119.0 2025-07-28 18:21:55+00:00         NaN
# ...         ...        ...        ...                       ...         ...
# 2760  38.298186  -0.716956      115.0 2025-07-28 19:07:51+00:00         NaN
# 2761  38.298154  -0.716924      115.0 2025-07-28 19:07:52+00:00         NaN
# 2762  38.298115  -0.716890      115.0 2025-07-28 19:07:53+00:00         NaN
# 2763  38.298076  -0.716856      115.0 2025-07-28 19:07:54+00:00         NaN
# 2764  38.298037  -0.716822      115.0 2025-07-28 19:07:55+00:00         NaN
#
#       cadence
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 2760      NaN
# 2761      NaN
# 2762      NaN
# 2763      NaN
# 2764      NaN
#
# [2765 rows x 6 columns]

# %%
plt.plot(df["heart_rate"])

# %%
plt.scatter(df["latitude"], df["longitude"], "-")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plt.scatter(df["latitude"], df["longitude"], "-")
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/pyplot.py:3903, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    3884 @_copy_docstring_and_deprecators(Axes.scatter)
#    3885 def scatter(
#    3886     x: float | ArrayLike,
#    (...)
#    3901     **kwargs,
#    3902 ) -> PathCollection:
# -> 3903     __ret = gca().scatter(
#    3904         x,
#    3905         y,
#    3906         s=s,
#    3907         c=c,
#    3908         marker=marker,
#    3909         cmap=cmap,
#    3910         norm=norm,
#    3911         vmin=vmin,
#    3912         vmax=vmax,
#    3913         alpha=alpha,
#    3914         linewidths=linewidths,
#    3915         edgecolors=edgecolors,
#    3916         plotnonfinite=plotnonfinite,
#    3917         **({"data": data} if data is not None else {}),
#    3918         **kwargs,
#    3919     )
#    3920     sci(__ret)
#    3921     return __ret
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/__init__.py:1473, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1470 @functools.wraps(func)
#    1471 def inner(ax, *args, data=None, **kwargs):
#    1472     if data is None:
# -> 1473         return func(
#    1474             ax,
#    1475             *map(sanitize_sequence, args),
#    1476             **{k: sanitize_sequence(v) for k, v in kwargs.items()})
#    1478     bound = new_sig.bind(ax, *args, **kwargs)
#    1479     auto_label = (bound.arguments.get(label_namer)
#    1480                   or bound.kwargs.get(label_namer))
#
# File ~/anaconda3/lib/python3.11/site-packages/matplotlib/axes/_axes.py:4796, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4792 s = np.ma.ravel(s)
#    4793 if (len(s) not in (1, x.size) or
#    4794         (not np.issubdtype(s.dtype, np.floating) and
#    4795          not np.issubdtype(s.dtype, np.integer))):
# -> 4796     raise ValueError(
#    4797         "s must be a scalar, "
#    4798         "or float array-like with the same size as x and y")
#    4800 # get the original edgecolor the user passed before we normalize
#    4801 orig_edgecolor = edgecolors
#
# ValueError: s must be a scalar, or float array-like with the same size as x and y
